# %%
# !pip install requests
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# BLOG LINK :-  https://medium.com/@henrik.schjoth/scraping-fbref-creating-a-pipeline-f5c9c23ba9da
import requests
import pandas as pd
import warnings
# Hide FutureWarnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# URL for Leeds 
team_url = "https://fbref.com/en/squads/b8fd03ef/Manchester-City-Stats"

# Sendeing HTTP GET-request to webpage
data = requests.get(team_url)

# check for success response (statuscode 200)
if data.status_code == 200:
    print("Successfully retrieved page")
else:
    print(f"Failed to retrieve page. Status code: {data.status_code}")
    print(data)
# Out:
# Failed to retrieve page. Status code: 403
# <Response [403]>

# %%
from curl_cffi import requests as cureq

response = cureq.get(url = "https://fbref.com/en/squads/b8fd03ef/Manchester-City-Stats", impersonate = "chrome")
print(response)
# Out:
# <Response [200]>

# %%
# Source - https://stackoverflow.com/a
# Posted by AntonioHerraizS, modified by community. See post 'Timeline' for change history
# Retrieved 2025-12-29, License - CC BY-SA 4.0

import requests

req = requests.Request('POST','http://stackoverflow.com',data='a=1&b=2')
prepared = req.prepare()

def pretty_print_POST(req):
    """
    At this point it is completely built and ready
    to be fired; it is "prepared".

    However pay attention at the formatting used in 
    this function because it is programmed to be pretty 
    printed and may differ from the actual request.
    """
    print('{}\n{}\r\n{}\r\n\r\n{}'.format(
        '-----------START-----------',
        req.method + ' ' + req.url,
        '\r\n'.join('{}: {}'.format(k, v) for k, v in req.headers.items()),
        req.body,
    ))

pretty_print_POST(prepared)
# Out:
# <Request [POST]>
# -----------START-----------
# POST http://stackoverflow.com/
# Content-Length: 7
#
# a=1&b=2

# %%
import requests

response = requests.post('http://httpbin.org/post', data={'key1': 'value1'})
print(response.request.url)
print(response.request.body)
print(response.content)
print(response.request.headers)
# Out:
# http://httpbin.org/post
# key1=value1
# b'{\n  "args": {}, \n  "data": "", \n  "files": {}, \n  "form": {\n    "key1": "value1"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Content-Length": "11", \n    "Content-Type": "application/x-www-form-urlencoded", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.32.3", \n    "X-Amzn-Trace-Id": "Root=1-69529726-6c22eae21309f63c2f83477a"\n  }, \n  "json": null, \n  "origin": "104.28.225.14", \n  "url": "http://httpbin.org/post"\n}\n'
# {'User-Agent': 'python-requests/2.32.3', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive', 'Content-Length': '11', 'Content-Type': 'application/x-www-form-urlencoded'}

# %%
# User-Agent': 'python-requests/2.32.3 this is important, as this is detected and fbref block it

# %%
#now to avoid this we will use user agent as browser

# %%
url = 'https://fbref.com/en/squads/b8fd03ef/Manchester-City-Stats'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36'
}

response = requests.get(url, headers=headers)
print(response)
#this will also fail
# Out:
# https://fbref.com/en/squads/b8fd03ef/Manchester-City-Stats

# %%
from curl_cffi import requests as cureq

response = cureq.get(url = "https://fbref.com/en/squads/b8fd03ef/Manchester-City-Stats", impersonate = "chrome")
print(response)
# Out:
# <Response [200]>

# %%
# print(response.content)
# Out:
# b'\n<!DOCTYPE html>\n<html data-version="klecko-" data-root="/home/fb/deploy/www" lang="en" class="no-js" >\n<head>\n    <meta charset="utf-8">\n    <meta http-equiv="x-ua-compatible" content="ie=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=2.0" />\n    <link rel="dns-prefetch" href="https://cdn.ssref.net/req/202512181" />\n<script>\n/* https://docs.osano.com/hc/en-us/articles/22469433444372-Google-Consent-Mode-v2  */\n  window.dataLayer = window.dataLayer ||[];\n      function gtag(){dataLayer.push(arguments);}\n      gtag(\'consent\',\'default\',{\n        \'ad_storage\':\'denied\',\n        \'analytics_storage\':\'denied\',\n        \'ad_user_data\':\'denied\',\n        \'ad_personalization\':\'denied\',\n        \'personalization_storage\':\'denied\',\n        \'functionality_storage\':\'granted\',\n        \'security_storage\':\'granted\',\n        \'wait_for_update\': 500\n      });\n      gtag("set", "ads_data_redaction", true
# ...
