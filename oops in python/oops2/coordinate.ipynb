# %%
class Point:
    def __init__(self,x,y):
        self.x=x
        self.y=y
    
    def __str__(self):
        return f"<{self.x},{self.y}>"
    def eucdist(self,pt2):
        return ((self.x-pt2.x)**2+(self.y-pt2.y)**2)**(1/2)
    def dist_from_zero(self):
        return self.eucdist(Point(0,0))

class Line:
    count=0
    def __init__(self,a,b,c):
        Line.count+=1
        self.a=a
        self.b=b
        self.c=c
    
    def slope(self):
        return -self.a/self.b
    
    def val(self,point):
        x=point.x
        y=point.y
        return x*self.a +y*self.b+self.c
        
    def ptposition(self,point):
        val=self.val(point)
        if (val==0):
            return "Point on the line"
        elif val>0:
            return "point over the line"
        else:
            return "point below the line"
    
    def pt_line_dist(self,pt):
        self.pt_line_dist(pt)
        val=self.val
