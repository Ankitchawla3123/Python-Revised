# %%
# Class relationship and inheritence 

# here name and gender a simple
# address is complicated so we craeted a classs for adddress

class Customer:
    def __init__(self,name,address,gender):
        self.name=name
        self.add=address
        self.gender=gender
    def printadd(self):
        print(self.add.city,self.add.pin,self.add.state)
    

class Address:
    def __init__(self,city,state,pin):
        self.city=city
        self.pin=pin
        self.state=state

# %%
add1=Address("N-D","new delhi",111111)
customer1=Customer("Ankit",add1,"male")

customer1.printadd()
# Out:
# N-D 111111 new delhi

# %%
# Class relationship and inheritence 

# here name and gender a simple
# address is complicated so we craeted a classs for adddress

class Customer:
    def __init__(self,name,address,gender):
        self.name=name
        self.add=address
        self.gender=gender
    def printadd(self):
        print(self.add.__city,self.add.pin,self.add.state)
    def printadd2(self):
        print(self.add.getcity(),self.add.pin,self.add.state)
    

class Address:
    def __init__(self,city,state,pin):
        self.__city=city # made the city variable private
        self.pin=pin
        self.state=state
    def getcity(self):
        return self.__city

# %%
add1=Address("N-D","new delhi",111111)
customer1=Customer("Ankit",add1,"male")

customer1.printadd2()
customer1.printadd()
# trying to access the private variable it's an issue
# so need to add a getter function or or use something like this _Classname__variablename
# Out:
# N-D 111111 new delhi
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 5
#       2 customer1=Customer("Ankit",add1,"male")
#       4 customer1.printadd2()
# ----> 5 customer1.printadd()
#       6 # trying to access the private variable it's an issue
#
# Cell In[5], line 12, in Customer.printadd(self)
#      11 def printadd(self):
# ---> 12     print(self.add.__city,self.add.pin,self.add.state)
#
# AttributeError: 'Address' object has no attribute '_Customer__city'

# %%
# Class relationship and inheritence 

# here name and gender a simple
# address is complicated so we craeted a classs for adddress

class Customer:
    def __init__(self,name,address,gender):
        self.name=name
        self.add=address
        self.gender=gender
    def printadd(self):
        print(self.add.__city,self.add.pin,self.add.state)
    def printadd2(self):
        print(self.add.getcity(),self.add.pin,self.add.state)
    def edit_profile(self,name,city, pin, state):
        self.name=name
        self.add=self.add.edit_address(city,pin,state)
    

class Address:
    def __init__(self,city,state,pin):
        self.__city=city # made the city variable private
        self.pin=pin
        self.state=state
    def getcity(self):
        return self.__city
    def edit_address(self,city,pin,state):
        self.__city=city
        self.pin=pin
        self.state=state
